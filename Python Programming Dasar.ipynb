# %% [markdown]
# # Python Programming Dasar
#
# Anda dapat mengkases website Python di [Python](http://python.org/). <br> Anda dapat mengunduh Anaconda di [Anaconda](http://anaconda.com/).
#
# ![Gambar CCTV](https://asset-a.grid.id/crop/0x0:1417x868/700x465/photo/2019/01/05/1877290494.jpg)
#
# ![Gambar CCTV 2](download.jpg)
# * * *

# %% [markdown]
# ## 1. Business Understanding
#
# ### 1.1 Latar Belakang
# * Karena **belum adanya data** mengenai *jumlah* jenis **_mobil_** di DKI Jakarta
# * Dan lain-lain
#     * List yang lain
#
# ### 1.2 Tujuan
# 1. Untuk membuat model prediksi jenis mobil dan nomor plat dari data CCTV
# 2. Untuk membantu pemerintah dalam membuat undang-undang pembatasan kendaraan bermotor
#     1. satu (tinggal tab saja, lalu ketik 1. akan otomatis menjadi A. B. C. dst)
#     2. dau
#     3. tiga
#
# ### 1.3 Manfaat
# ***

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# ## 6. Presentation

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print(2+5)
# Out:
# 7

# %%
print(5-10)
# Out:
# -5

# %%
apple= 10
orange = 6

print('apple value=')
print(apple)
print('orange value=')
print(orange)
print('apple+orange value=')
print (orange+apple)
# Out:
# apple value=
# 10
# orange value=
# 6
# apple+orange value=
# 16

# %%
print (True)
# Out:
# True

# %%
print (type(True))
# Out:
# <class 'bool'>

# %%
print (apple==orange)
# Out:
# False

# %%
Fam = [2,3,5,7]

# %%
print (Fam)
# Out:
# [2, 3, 5, 7]

# %%
type(Fam)
# Out:
# list

# %%
Data=[["Bob", 160],["Charlie", 165], ["Delta", 155]]

Data

Data[0]

Data[0][0]
# Out:
# 'Bob'

# %%
print(Data)
# Out:
# [['Bob', 160], ['Charlie', 165], ['Delta', 155]]

# %%
print(Data)
x,y=max(Data, key=lambda a:a[1])
print(x)
print(y)
# Out:
# [['Bob', 160], ['Charlie', 165], ['Delta', 155]]
# Charlie
# 165

# %%
print(max(Fam))
print(min(Fam))
# Out:
# 7
# 2

# %%
name="hello world"
print(name)
print(type(name))
# hello world type is string
print(name.capitalize())
print(name.upper())
print(name.lower())
print(name.lower())
print(name.strip()) #jika ada space di awal dan diakhir string, maka space tersebut akan hilang
# Out:
# hello world
# <class 'str'>
# Hello world
# HELLO WORLD
# hello world
# hello world
# hello world

# %%
name1="Dwilaras Athina .com"
print(name1.strip(".com"))
# Out:
# Dwilaras Athina

# %%
animals=['cat','dog', 'monkey','chicken', 'bird', 'duck']

for animal in animals:
    print (animal)
    nums = [0,1,2,3,4]
    squares = [x**2 for x in nums]
print (squares)
# Out:
# cat
# dog
# monkey
# chicken
# bird
# duck
# [0, 1, 4, 9, 16]

# %%
name[1:5]
# Out:
# 'ello'

# %%
name[0:7]
# Out:
# 'hello w'

# %%
HargaWortel=10000
type(HargaWortel)
# Out:
# int

# %%
RatingChannelX=5.9
type(RatingChannelX)
# Out:
# float

# %%
nama_variable = 'Phyton untuk pemula'
print(type(nama_variable))
print(nama_variable[0])
print(nama_variable[-1])
print(nama_variable[0:5])
print(nama_variable[1:-1])
# Out:
# <class 'str'>
# P
# a
# Phyto
# hyton untuk pemul

# %%
a=10
b=20
c=30

if a==b:
    print ('yes')
elif a==c:
    print ('yes')
else:
    print ('no')
# Out:
# no

# %%
# Import numpy

import numpy as np

# %%
height_list=[row[1] for row in Data]

# %%
height_list
# Out:
# [160, 165, 155]

# %%
print(type(height_list))
# Out:
# <class 'list'>

# %%
height_array=np.array(height_list)

# %%
height_array
# Out:
# array([160, 165, 155])

# %%
print(type(height_array))
# Out:
# <class 'numpy.ndarray'>

# %%
#contoh list
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# %%
ind_ger=countries.index('germany')

# %%
ind_ger
# Out:
# 2

# %%
print(capitals[ind_ger])
# Out:
# berlin

# %%
#contoh dictionary
europe = {'spain':['madrid'], 'france':['paris'], 'germany':['berlin'], 'norway':['oslo']}

# %%
type(europe)
# Out:
# dict

# %%
print(europe)
# Out:
# {'spain': ['madrid'], 'france': ['paris'], 'germany': ['berlin'], 'norway': ['oslo']}

# %%
#dependent variable of europe
print(europe.keys())
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])

# %%
#independent variable of europe
print(europe.values())
# Out:
# dict_values([['madrid'], ['paris'], ['berlin'], ['oslo']])

# %%
print(europe['norway'])
# Out:
# ['oslo']

# %%
#import pandas
import pandas as pd

# %%
#Build dataframe from dictionary 
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(europe)
# Out:
#   france germany norway   spain
# 0  paris  berlin   oslo  madrid

# %%
pd.read_csv('IMDB-database.csv', encoding='latin1')
# Out:
#       movie_ID                                movie_title  duration  color  \
# 0            1                                     Avatar       178      1
# 1            2   Pirates of the Caribbean: At World's End       169      1
# 2            3                      The Dark Knight Rises       164      1
# 3            4                               Spider-Man 3       156      1
# 4            5         Batman v Superman: Dawn of Justice       183      1
# 5            6                           Superman Returns       169      1
# 6            7                               Man of Steel       143      1
# 7            8  The Hobbit: The Battle of the Five Armies       164      1
# 8            9                     The Amazing Spider-Man       153      1
# 9           10                                 Robin Hood       156      1
# 10          11                                  King Kong       201      1
# ...

# %%
data_imdb=pd.read_csv('https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database.csv', encoding='Latin1')

# %%
data_imdb.head()
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
code = ['US', 'AUS', 'JPN', 'IN', 'RUS', 'MOR', 'EG'] 
names = ['United States', 'Australia', 'Japan', 'India', 'Russia','Morocco', 'Egypt'] 
dr = [True, False, False, False, True, True, True] 
cpc = [809, 731, 588, 18, 200, 70, 45]

# %%
# Create dictionary my_dict with three key:value pairs: my_dict 
my_dict = {'ctrcode':code, 'country':names, 'drives_right':dr, 'cars_per_cap':cpc}
cars = pd.DataFrame(my_dict)
print(type(cars)) 
print(cars)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    cars_per_cap        country ctrcode  drives_right
# 0           809  United States      US          True
# 1           731      Australia     AUS         False
# 2           588          Japan     JPN         False
# 3            18          India      IN         False
# 4           200         Russia     RUS          True
# 5            70        Morocco     MOR          True
# 6            45          Egypt      EG          True

# %%
# Dimension 
cars.shape 
print(cars.columns) 
print(len(cars.columns)) 
print(len(cars))
# Out:
# Index(['cars_per_cap', 'country', 'ctrcode', 'drives_right'], dtype='object')
# 4
# 7

# %%
# Brief View 
cars.head(3)
# Out:
#    cars_per_cap        country ctrcode  drives_right
# 0           809  United States      US          True
# 1           731      Australia     AUS         False
# 2           588          Japan     JPN         False

# %%
cars.tail(3)
# Out:
#    cars_per_cap  country ctrcode  drives_right
# 4           200   Russia     RUS          True
# 5            70  Morocco     MOR          True
# 6            45    Egypt      EG          True

# %%
# Data type 
cars.dtypes
# Out:
# cars_per_cap     int64
# country         object
# ctrcode         object
# drives_right      bool
# dtype: object

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
# cars_per_cap    7 non-null int64
# country         7 non-null object
# ctrcode         7 non-null object
# drives_right    7 non-null bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 255.0+ bytes

# %%
# Summary Statistics 
cars.describe()
# Out:
#        cars_per_cap
# count      7.000000
# mean     351.571429
# std      345.595552
# min       18.000000
# 25%       57.500000
# 50%      200.000000
# 75%      659.500000
# max      809.000000

# %%
# Set DF Column Index  --> movie ID nya jadikan sebagai index
data_imdb_id = data_imdb.set_index("movie_ID") 
data_imdb_id
# Out:
#                                         movie_title  duration  color  \
# movie_ID
# 1                                            Avatar       178      1
# 2          Pirates of the Caribbean: At World's End       169      1
# 3                             The Dark Knight Rises       164      1
# 4                                      Spider-Man 3       156      1
# 5                Batman v Superman: Dawn of Justice       183      1
# 6                                  Superman Returns       169      1
# 7                                      Man of Steel       143      1
# 8         The Hobbit: The Battle of the Five Armies       164      1
# 9                            The Amazing Spider-Man       153      1
# 10                                       Robin Hood       156      1
# 11                                        King Kong       201      1
# 12                                          Titanic       194      1
# ...

# %%
print(cars_id.shape)
# Out:
# (7, 3)

# %%
cars_id
# Out:
#          cars_per_cap        country  drives_right
# ctrcode
# US                809  United States          True
# AUS               731      Australia         False
# JPN               588          Japan         False
# IN                 18          India         False
# RUS               200         Russia          True
# MOR                70        Morocco          True
# EG                 45          Egypt          True

# %%
#indexing and selecting data 

#column access :
cars_id['country']
# Out:
# ctrcode
# US     United States
# AUS        Australia
# JPN            Japan
# IN             India
# RUS           Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
cars_id[['country']]
# Out:
#                country
# ctrcode
# US       United States
# AUS          Australia
# JPN              Japan
# IN               India
# RUS             Russia
# MOR            Morocco
# EG               Egypt

# %%
#row access
cars_id[0:3]
# Out:
#          cars_per_cap        country  drives_right
# ctrcode
# US                809  United States          True
# AUS               731      Australia         False
# JPN               588          Japan         False

# %%
#LOC (label based)
# row access 

cars_id.loc[['AUS', 'EG']]
# Out:
#          cars_per_cap    country  drives_right
# ctrcode
# AUS               731  Australia         False
# EG                 45      Egypt          True

# %%
#Row & Column access : 
cars_id.loc[['RUS', 'MOR'], ['country', 'drives_right']]
# Out:
#          country  drives_right
# ctrcode
# RUS       Russia          True
# MOR      Morocco          True

# %%
#iLOC (integer index based) 
#Row access : 
cars_id.iloc[[1, 6]]
# Out:
#          cars_per_cap    country  drives_right
# ctrcode
# AUS               731  Australia         False
# EG                 45      Egypt          True

# %%
#Row & Column access : 
cars_id.iloc[[4,5], [1,2]]
# Out:
#          country  drives_right
# ctrcode
# RUS       Russia          True
# MOR      Morocco          True

# %%
#Where Clause and Sort

#WHERE yang hanya mengendarai di kanan

print(cars_id[cars_id.drives_right == True])
# Out:
#          cars_per_cap        country  drives_right
# ctrcode
# US                809  United States          True
# RUS               200         Russia          True
# MOR                70        Morocco          True
# EG                 45          Egypt          True

# %%
#WHERE cars per cap > 100 and id country Australia
print(cars_id[(cars_id.cars_per_cap > 100) & (cars_id.country == "Australia") ])
# Out:
#          cars_per_cap    country  drives_right
# ctrcode
# AUS               731  Australia         False

# %%
#SORT
#sorting by cars per cap
cars_id.sort_values(by=['cars_per_cap'])
# Out:
#          cars_per_cap        country  drives_right
# ctrcode
# IN                 18          India         False
# EG                 45          Egypt          True
# MOR                70        Morocco          True
# RUS               200         Russia          True
# JPN               588          Japan         False
# AUS               731      Australia         False
# US                809  United States          True

# %%
#SORT untuk descending
cars_id.sort_values(by=['cars_per_cap'], ascending=False)
# Out:
#          cars_per_cap        country  drives_right
# ctrcode
# US                809  United States          True
# AUS               731      Australia         False
# JPN               588          Japan         False
# RUS               200         Russia          True
# MOR                70        Morocco          True
# EG                 45          Egypt          True
# IN                 18          India         False

# %%
dataupdate_imdb=pd.read_csv('https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database-update.csv', encoding='Latin1')
dataupdate_imdb.head()
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
#How many rows and columns reflected on dataset file IMDB-database-update.csv?

dataupdate_imdb.shape
# Out:
# (3781, 36)

# %%
dataupdate_imdb.head(3)
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# 1      ...                       1                    1000
# 2      ...                       1                   23000
#
#   cast_total_facebook_likes movie_facebook?  movie_facebook_likes;  \
# 0                      4834               1                  33000
# ...

# %%
# Example 
dataupdate_imdb[["movie_facebook?"]] = dataupdate_imdb[["movie_facebook?"]].astype('str')

# %%
#Missing data

dataupdate_imdb.isnull().sum()
# Out:
# movie_ID                     0
# movie_title                  0
# duration                     0
# color                        0
# title_year                   0
# country                      0
# language                     0
# content_rating               0
# budget_USD                   0
# gross_USD                    0
# net_USD                      0
# profitable                   0
# director_name                0
# director_top20?              0
# director_facebook?           0
# director_facebook_likes      0
# actor_1_name                 0
# actor_top20?                 0
# actor_1_facebook?            0
# actor_1_facebook_likes       0
# actor_2_name                 0
# actor_top20?.1               0
# actor_2_facebook?            0
# actor_2_facebook_likes       0
# actor_3_name                 0
# actor_top20?.2               0
# actor_3_facebook?            0
# actor_3_facebook_likes       0
# cast_total_facebook_likes    0
# movie_facebook?              0
# ...

# %%
#Drop missing data to handle missing data

dataupdate_imdb = dataupdate_imdb.drop_duplicates()

# %%
dataupdate_imdb
# Out:
#       movie_ID                                movie_title  duration  color  \
# 0            1                                     Avatar       178      1
# 1            2   Pirates of the Caribbean: At World's End       169      1
# 2            3                      The Dark Knight Rises       164      1
# 3            4                               Spider-Man 3       156      1
# 4            5         Batman v Superman: Dawn of Justice       183      1
# 5            6                           Superman Returns       169      1
# 6            7                               Man of Steel       143      1
# 7            8  The Hobbit: The Battle of the Five Armies       164      1
# 8            9                     The Amazing Spider-Man       153      1
# 9           10                                 Robin Hood       156      1
# 10          11                                  King Kong       201      1
# ...

# %%
# Get Started with your data
#  Find summary statistics 
# Find which variables has high correlation to imdb_score

#Example for duration and gross_USD 
dataupdate_imdb[["duration", "gross_USD"]].describe()
# Out:
#           duration     gross_USD
# count  3781.000000  3.781000e+03
# mean    109.950278  5.182002e+07
# std      22.299267  7.003776e+07
# min      37.000000  1.620000e+02
# 25%      95.000000  7.605668e+06
# 50%     106.000000  2.896520e+07
# 75%     120.000000  6.600997e+07
# max     325.000000  7.605058e+08

# %%
# Categoric variables 
# Find count of each category-level

# Example 
dataupdate_imdb["color"].value_counts()
# Out:
# 1    3657
# 0     124
# Name: color, dtype: int64

# %%
#menghitung content rating 
dataupdate_imdb["content_rating"].value_counts()
# Out:
# R            1715
# PG-13        1311
# PG            568
# G              88
# Not Rated      39
# Unrated        24
# Approved       14
# X              10
# NC-17           6
# Passed          3
# M               2
# GP              1
# Name: content_rating, dtype: int64

# %%
# High Rating movies criteria 
# Clue 
    # Let’s set imdb_score benchmark as High-Rating movie with imdb_score > 7.5
    # Create new variables “score_group” (“High” if imdb_score > 7.5 and “Low” if imdb <= 7.5)
    # Analyze at least 5 variables from which you can start figure out criteria of high rated movie
    # If there’s still extra time, analyze 5 more variables to strengthen criteria of high rated movies

# %%
dataupdate_imdb[dataupdate_imdb.imdb_score>7.5]
# Out:
#       movie_ID                                      movie_title  duration  \
# 0            1                                           Avatar       178
# 2            3                            The Dark Knight Rises       164
# 11          12                                          Titanic       194
# 12          13                       Captain America: Civil War       147
# 15          16                                          Skyfall       143
# 26          27                          Star Trek Into Darkness       132
# 29          30                                           WALL-E        98
# 32          33                                  The Dark Knight       152
# 36          37                                  The Jungle Book       106
# 38          39                   Dawn of the Planet of the Apes       130
# 39          40                                       Big Hero 6       102
# 42          43                         How to Train Your Dragon        98
# ...

# %%
# Create new variables “score_group” (“High” if imdb_score > 7.5 and “Low” if imdb <= 7.5)

def score (imdb_score) : 
    if imdb_score>7.5:
        return("High")
    else:
        return("Low")

list(map(score, dataupdate_imdb.imdb_score))

dataupdate_imdb['score_group']=list(map(score, dataupdate_imdb.imdb_score))

# %%
dataupdate_imdb.columns
# Out:
# Index(['movie_ID', 'movie_title', 'duration', 'color', 'title_year', 'country',
#        'language', 'content_rating', 'budget_USD', 'gross_USD', 'net_USD',
#        'profitable', 'director_name', 'director_top20?', 'director_facebook?',
#        'director_facebook_likes', 'actor_1_name', 'actor_top20?',
#        'actor_1_facebook?', 'actor_1_facebook_likes', 'actor_2_name',
#        'actor_top20?.1', 'actor_2_facebook?', 'actor_2_facebook_likes',
#        'actor_3_name', 'actor_top20?.2', 'actor_3_facebook?',
#        'actor_3_facebook_likes', 'cast_total_facebook_likes',
#        'movie_facebook?', 'movie_facebook_likes;', 'facenumber_in_poster',
#        'num_voted_users', 'num_user_for_reviews', 'imdb_score', 'imdb_top_250',
#        'score_group'],
#       dtype='object')

# %% [markdown]
# # Individual Assignment

# %%
dataupdate_imdb=pd.read_csv('https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database-update.csv', encoding='Latin1')
dataupdate_imdb.head()
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
# How many rows and columns reflected on dataset file IMDB-database-update.csv

dataupdate_imdb.shape
# Out:
# (3781, 36)

# %%
dataupdate_imdb[dataupdate_imdb.title_year==2013].sort_values(by=['net_USD'],ascending=False).head(3)
# Out:
#       movie_ID                      movie_title  duration  color  title_year  \
# 1614      1615  The Hunger Games: Catching Fire       146      1        2013
# 236        237                  Despicable Me 2        98      1        2013
# 57          58                           Frozen       102      1        2013
#
#      country language content_rating  budget_USD  gross_USD      ...       \
# 1614     USA  English          PG-13   130000000  424645577      ...
# 236      USA  English             PG    76000000  368049635      ...
# 57       USA  English             PG   150000000  400736600      ...
#
#       actor_3_facebook?  actor_3_facebook_likes cast_total_facebook_likes  \
# 1614                  1                     523                     49355
# 236                   1                    1000                     11905
# 57                    1                     490                      2582
#
#      movie_facebook?  movie_facebook_likes;  facenumber_in_poster  \
# ...

# %%
dataupdate_imdb[dataupdate_imdb.title_year==2009].sort_values(by=['net_USD'],ascending=False).head(3)
# Out:
#       movie_ID                  movie_title  duration  color  title_year  \
# 0            1                       Avatar       178      1        2009
# 2669      2670  The Twilight Saga: New Moon       130      1        2009
# 3197      3198                 The Hangover       108      1        2009
#
#      country language content_rating  budget_USD  gross_USD      ...       \
# 0        USA  English          PG-13   237000000  760505847      ...
# 2669     USA  English          PG-13    50000000  296623634      ...
# 3197     USA  English              R    35000000  277313371      ...
#
#       actor_3_facebook?  actor_3_facebook_likes cast_total_facebook_likes  \
# 0                     1                     855                      4834
# 2669                  1                   12000                     64040
# 3197                  1                     706                     17623
#
#      movie_facebook?  movie_facebook_likes;  facenumber_in_poster  \
# ...

# %%
len(dataupdate_imdb[dataupdate_imdb.language!="English"])
# Out:
# 153

# %%
a=dataupdate_imdb["language"].value_counts(). head(4)

# %%
a
# Out:
# English     3628
# French        33
# Spanish       23
# Mandarin      14
# Name: language, dtype: int64

# %%
a.tail(3)
# Out:
# French      33
# Spanish     23
# Mandarin    14
# Name: language, dtype: int64

# %%
dataupdate_imdb.groupby('country').sum().sort_values(by='net_USD',ascending=False).head(3)
# Out:
#            movie_ID  duration  color  title_year    budget_USD     gross_USD  \
# country
# USA         5675953    329223   2924     6027180  121680335210  173684268384
# UK           617519     35921    306      636498    9972938734   11504553258
# Australia     68124      4116     38       78062    1411705523    1664277139
#
#                net_USD  profitable  director_facebook?  \
# country
# USA        52003933174        1729                2494
# UK          1531614524         138                 263
# Australia    252571616          18                  33
#
#            director_facebook_likes      ...       actor_3_facebook?  \
# country                                 ...
# USA                        2769868      ...                    2989
# UK                           94324      ...                     316
# Australia                     9118      ...                      39
#
#            actor_3_facebook_likes  cast_total_facebook_likes  movie_facebook?  \
# country
# ...

# %%
mean2013=dataupdate_imdb[dataupdate_imdb['title_year']==2013]
mean2013count=mean2013['budget_USD'].mean()

# %%
mean2013count
# Out:
# 51069610.77439024

# %%
mean2014=dataupdate_imdb[dataupdate_imdb['title_year']==2014]
mean2014count=mean2014['budget_USD'].mean()
mean2014count
# Out:
# 49919006.62251656

# %%
mean2014count>mean2013count
# Out:
# False

# %%
mean2014count<mean2013count
# Out:
# True

# %%
dataupdate_imdb_high=dataupdate_imdb.sort_values(by=['net_USD'],ascending=False)
dataupdate_imdb_high[['movie_title','budget_USD','net_USD']].head(1)
# Out:
#   movie_title  budget_USD    net_USD
# 0      Avatar   237000000  523505847
